# %% [markdown]
# # Introduction

# %% [markdown]
#  - The main point of interest for this project is to find a suitable area where to find the optimum place where to start a businness, which kind is going to be clarified as well by the results of this analysis.
#  - Any person interested in starting a businnes inside or around this area, or interested into a market analysis able to predict possible new activities that may have a negative impact on his/her businness in that area might find this project useful.

# %% [markdown]
# # Data
#
# The main source of data is a local database, as not much informations are available about this particular place.
# After gathering all the important features, Foursquare API will handle the exploration to find relevant venues and tendencies.
# Data will be merged and crossed along with the main features (area in kms, population density) and showed via folium map.
# In the end, data will be clustered as a number equal to the cluster of possibilities appear to the use of the customer.

# %%
from bs4 import BeautifulSoup
from lxml import etree
import urllib.request


# Setup webpage downloader
with urllib.request.urlopen("https://www.comuniecitta.it/sicilia-19/provincia-di-siracusa-89/comuni") as url:
    s = url.read()

html = etree.HTML(s)

# Use BeautifulSoup to extract the table
target = s
soup = BeautifulSoup(target,'html.parser')
tAll = soup.find_all('table')

# First stage: download the table
for i in range(len(tAll)):
    try:
        # 1.1 Extract every header
        th = tAll[i].find_all("th")

        # 1.2 Extract every item
        td = tAll[i].find_all("td")
        
    except:
        pass
    
# Second stage: save filtered data into RAM

# 2.0 Initialize lists
columns = []
rows = []

# 2.1 Save headers as columns
for i in range(len(th)):
    columns.append(th[i].text)
    
# 2.1.1 Initialize empty row for each column
for i in range(len(columns)):
    rows.append([])

#2.2 Save each row in the corresponding column
y = 0
for x in range(len(rows)):
    y = 0 + x
    while y <= len(td) -1:
        rows[x].append(td[y].text)
        y += (3 - x) + x
    y = 0 + x
        

print(columns)
print(rows)
# Out:
# ['Comune', 'Superficie', 'Popolazione']
# [[' Siracusa', 'Augusta', 'Avola', 'Buccheri', 'Buscemi', 'Canicattini Bagni', 'Carlentini', 'Cassaro', 'Ferla', 'Floridia', 'Francofonte', 'Lentini', 'Melilli', 'Noto', 'Pachino', 'Palazzolo Acreide', 'Portopalo di Capo Passero', 'Priolo Gargallo', 'Rosolini', 'Solarino', 'Sortino'], ['204,10 km2', '109,30 km2', '74,30 km2', '57,40 km2', '51,60 km2', '15,10 km2', '158,00 km2', '19,40 km2', '24,80 km2', '26,20 km2', '74,00 km2', '215,80 km2', '136,10 km2', '551,10 km2', '50,50 km2', '86,30 km2', '14,90 km2', '57,60 km2', '76,20 km2', '13,00 km2', '93,20 km2'], ['123.850', '34.539', '31.827', '2.148', '1.147', '7.355', '17.587', '819', '2.599', '23.050', '12.392', '24.017', '13.304', '24.047', '21.990', '9.061', '3.818', '12.148', '21.798', '7.820', '8.955']]

# %%
# Third stage: convert lists into pandas dataframe
import pandas as pd

syracuse_province = pd.DataFrame({columns[0]:rows[0],columns[1]:rows[1],columns[2]:rows[2]})
syracuse_province
# Out:
#                        Comune  Superficie Popolazione
# 0                    Siracusa  204,10 km2     123.850
# 1                     Augusta  109,30 km2      34.539
# 2                       Avola   74,30 km2      31.827
# 3                    Buccheri   57,40 km2       2.148
# 4                     Buscemi   51,60 km2       1.147
# 5           Canicattini Bagni   15,10 km2       7.355
# 6                  Carlentini  158,00 km2      17.587
# 7                     Cassaro   19,40 km2         819
# 8                       Ferla   24,80 km2       2.599
# 9                    Floridia   26,20 km2      23.050
# 10                Francofonte   74,00 km2      12.392
# 11                    Lentini  215,80 km2      24.017
# 12                    Melilli  136,10 km2      13.304
# 13                       Noto  551,10 km2      24.047
# 14                    Pachino   50,50 km2      21.990
# 15          Palazzolo Acreide   86,30 km2       9.061
# 16  Portopalo di Capo Passero   14,90 km2       3.818
# 17            Priolo Gargallo   57,60 km2      12.148
# 18                   Rosolini   76,20 km2      21.798
# 19                   Solarino   13,00 km2       7.820
# 20                    Sortino   93,20 km2       8.955

# %% [markdown]
# ## Get coordinates using Geocoder package

# %%
# Fourth stage: find GPS coordinates for each city

# 4.1 Initialization

# 4.1.1 Initalize geocoder
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="syracuse_agent")

# 4.1.2 Initalize new column in dataframe
syracuse_province['Latitude'] = ""
syracuse_province['Longitude'] = ""

# 4.2 Localize and record position for each city in the dataframe
for index, row in syracuse_province.iterrows():
    location = geolocator.geocode("{}, Siracusa".format(row['Comune']))
    row['Latitude'] = location.latitude
    row['Longitude'] = location.longitude

syracuse_province
# Out:
#                        Comune  Superficie Popolazione Latitude Longitude
# 0                    Siracusa  204,10 km2     123.850  37.0646   15.2907
# 1                     Augusta  109,30 km2      34.539  37.2369   15.2197
# 2                       Avola   74,30 km2      31.827  36.9095    15.135
# 3                    Buccheri   57,40 km2       2.148  37.1265   14.8504
# 4                     Buscemi   51,60 km2       1.147  37.0855   14.8842
# 5           Canicattini Bagni   15,10 km2       7.355  37.0349   15.0623
# 6                  Carlentini  158,00 km2      17.587  37.2759    15.015
# 7                     Cassaro   19,40 km2         819  37.1069   14.9476
# 8                       Ferla   24,80 km2       2.599  37.1186   14.9411
# 9                    Floridia   26,20 km2      23.050  37.0869   15.1519
# 10                Francofonte   74,00 km2      12.392  37.2266   14.8819
# 11                    Lentini  215,80 km2      24.017  37.2847   14.9988
# 12                    Melilli  136,10 km2      13.304  37.1783   15.1266
# 13                       Noto  551,10 km2      24.047  36.8909   15.0706
# 14                    Pachino   50,50 km2      21.990  36.7152   15.0915
# 15          Palazzolo Acreide   86,30 km2       9.061  37.0619   14.9039
# 16  Portopalo di Capo Passero   14,90 km2       3.818  36.6838   15.1333
# 17            Priolo Gargallo   57,60 km2      12.148  37.1579    15.186
# 18                   Rosolini   76,20 km2      21.798  36.8205   14.9526
# 19                   Solarino   13,00 km2       7.820  37.1012    15.119
# 20                    Sortino   93,20 km2       8.955  37.1569   15.0277

# %% [markdown]
# # Methodology
# - Explore and Cluster the neighborhoods in Syracuse.
# - Find all venues with Foursquare API.
# - Explore each neighborhood invidually.
# - Cluster the neighborhoods to find optimum spots to open a determinate type of businness.

# %% [markdown]
# ## Explore and cluster the neighborhoods in Syracuse

# %%
latitude = syracuse_province["Latitude"][0]
longitude = syracuse_province["Longitude"][0]
print('The geograpical coordinate of Syracuse are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Syracuse are 37.0646139, 15.2907196.

# %% [markdown]
# ### Create a map of Syracuse

# %%
import folium # map rendering library

# create map of New York using latitude and longitude values
map_syracuse = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough in zip(syracuse_province['Latitude'], syracuse_province['Longitude'], syracuse_province['Comune']):
    label = '{}'.format(borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_syracuse)  
    
map_syracuse
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Log into Foursquare and explore Syracuse's venues

# %%
CLIENT_ID = 'QEKVYOHVSMWOW12V2S1T3HIRUQP3B02W342Z2TWNTMQH20EP' # your Foursquare ID
CLIENT_SECRET = '344DWOTSL3IKCM4B1XRFSZ2MTHWR1WRBTIB3BKCW0RE3PLCK' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QEKVYOHVSMWOW12V2S1T3HIRUQP3B02W342Z2TWNTMQH20EP
# CLIENT_SECRET:344DWOTSL3IKCM4B1XRFSZ2MTHWR1WRBTIB3BKCW0RE3PLCK

# %%
import requests

# Fifth stage: setup a function to retrieve a DataFrame containing nearby venues
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            500, 
            100)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
syracuse_venues = getNearbyVenues(names=syracuse_province['Comune'],
                                   latitudes=syracuse_province['Latitude'],
                                   longitudes=syracuse_province['Longitude']
                                  )
# Out:
#  Siracusa
# Augusta
# Avola
# Buccheri
# Buscemi
# Canicattini Bagni
# Carlentini
# Cassaro
# Ferla
# Floridia
# Francofonte
# Lentini
# Melilli
# Noto
# Pachino
# Palazzolo Acreide
# Portopalo di Capo Passero
# Priolo Gargallo
# Rosolini
# Solarino
# Sortino

# %%
print('There are {} uniques categories.'.format(len(syracuse_venues['Venue Category'].unique())))
syracuse_venues
# Out:
# There are 63 uniques categories.
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0       Siracusa              37.064614               15.290720
# 1       Siracusa              37.064614               15.290720
# 2       Siracusa              37.064614               15.290720
# 3       Siracusa              37.064614               15.290720
# 4       Siracusa              37.064614               15.290720
# ..           ...                    ...                     ...
# 155      Sortino              37.156854               15.027716
# 156      Sortino              37.156854               15.027716
# 157      Sortino              37.156854               15.027716
# 158      Sortino              37.156854               15.027716
# 159      Sortino              37.156854               15.027716
#
#                                           Venue  Venue Latitude  \
# 0                               La Voglia Matta       37.065380
# 1                           Piano B Casual Food       37.064811
# 2                            Caseificio Borderi       37.065452
# 3                               Ponte Umbertino       37.064959
# 4    Il Leggendario Panino Da Antonio & Daniele       37.065794
# ..                                          ...             ...
# 155                             I QUATTRO CANTI       37.158434
# 156       Ristorante Pizzoleria I Quattro Canti       37.158275
# 157                                      Nabila       37.158643
# 158                               Piccole Gioie       37.159001
# 159                               La Pizzoleria       37.159001
#
#      Venue Longitude      Venue Category
# 0          15.288889      Ice Cream Shop
# 1          15.288139  Italian Restaurant
# 2          15.293635       Deli / Bodega
# 3          15.290439       Historic Site
# 4          15.290896          Food Truck
# ..               ...                 ...
# 155        15.027846               Plaza
# 156        15.028132         Pizza Place
# 157        15.029019          Restaurant
# 158        15.027898           Gift Shop
# 159        15.025455         Pizza Place
#
# [160 rows x 7 columns]

# %% [markdown]
# ### Analyze each neighborhood

# %%
# Sixth stage: One Hot Encoding

# one hot encoding
syracuse_onehot = pd.get_dummies(syracuse_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
syracuse_onehot['Neighborhood'] = syracuse_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [syracuse_onehot.columns[-1]] + list(syracuse_onehot.columns[:-1])
syracuse_onehot = syracuse_onehot[fixed_columns]

syracuse_onehot.head()

# Group neighborhoods
syracuse_grouped = syracuse_onehot.groupby('Neighborhood').mean().reset_index()
syracuse_grouped
# Out:
#                  Neighborhood  Art Museum    Bakery       Bar     Beach  \
# 0                    Siracusa    0.000000  0.016667  0.000000  0.000000
# 1                     Augusta    0.000000  0.000000  0.000000  0.166667
# 2                       Avola    0.000000  0.000000  0.000000  0.000000
# 3                    Buccheri    0.000000  0.000000  0.000000  0.000000
# 4                     Buscemi    0.000000  0.000000  0.000000  0.000000
# 5           Canicattini Bagni    0.250000  0.000000  0.000000  0.000000
# 6                     Cassaro    0.000000  0.000000  0.000000  0.000000
# 7                       Ferla    0.000000  0.000000  0.000000  0.000000
# 8                    Floridia    0.000000  0.000000  0.000000  0.000000
# 9                 Francofonte    0.000000  0.000000  0.250000  0.000000
# 10                    Lentini    0.000000  0.250000  0.000000  0.000000
# 11                    Melilli    0.000000  0.000000  0.333333  0.000000
# 12                       Noto    0.038462  0.000000  0.000000  0.000000
# 13                    Pachino    0.000000  0.000000  0.000000  0.000000
# 14          Palazzolo Acreide    0.000000  0.000000  0.000000  0.000000
# 15  Portopalo di Capo Passero    0.000000  0.000000  0.000000  0.111111
# 16            Priolo Gargallo    0.000000  0.000000  0.000000  0.000000
# 17                   Rosolini    0.000000  0.000000  0.000000  0.000000
# 18                   Solarino    0.000000  0.000000  0.000000  0.000000
# 19                    Sortino    0.000000  0.000000  0.000000  0.000000
#
#       Bistro  Breakfast Spot   Brewery  Burger Joint  Cafeteria  ...   Pub  \
# 0   0.033333        0.016667  0.016667          0.00   0.016667  ...  0.00
# 1   0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 2   0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 3   0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 4   0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 5   0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 6   0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 7   0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 8   0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 9   0.000000        0.000000  0.000000          0.00   0.000000  ...  0.25
# 10  0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 11  0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 12  0.076923        0.000000  0.000000          0.00   0.000000  ...  0.00
# 13  0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 14  0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 15  0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 16  0.000000        0.000000  0.000000          0.20   0.000000  ...  0.00
# 17  0.000000        0.250000  0.000000          0.25   0.000000  ...  0.25
# 18  0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
# 19  0.000000        0.000000  0.000000          0.00   0.000000  ...  0.00
#
#     Restaurant  Sandwich Place  Sculpture Garden  Seafood Restaurant  \
# 0     0.050000        0.016667          0.000000            0.083333
# 1     0.000000        0.000000          0.166667            0.166667
# 2     0.000000        0.000000          0.000000            0.000000
# 3     0.000000        0.000000          0.000000            0.000000
# 4     0.000000        0.000000          0.000000            0.000000
# 5     0.250000        0.000000          0.000000            0.000000
# 6     1.000000        0.000000          0.000000            0.000000
# 7     0.000000        0.000000          0.000000            0.000000
# 8     0.000000        0.000000          0.000000            0.000000
# 9     0.000000        0.000000          0.000000            0.000000
# 10    0.000000        0.000000          0.000000            0.000000
# 11    0.000000        0.000000          0.000000            0.000000
# 12    0.076923        0.000000          0.000000            0.000000
# 13    0.000000        0.000000          0.000000            0.000000
# 14    0.000000        0.000000          0.000000            0.000000
# 15    0.111111        0.000000          0.000000            0.111111
# 16    0.000000        0.000000          0.000000            0.000000
# 17    0.000000        0.000000          0.000000            0.000000
# 18    0.000000        0.000000          0.000000            0.000000
# 19    0.200000        0.000000          0.000000            0.000000
#
#     Snack Place  Spanish Restaurant  Tennis Court   Theater  Trattoria/Osteria
# 0      0.000000            0.016667           0.0  0.000000           0.016667
# 1      0.000000            0.000000           0.0  0.000000           0.000000
# 2      0.000000            0.000000           0.0  0.000000           0.000000
# 3      0.000000            0.000000           0.0  0.333333           0.000000
# 4      0.000000            0.000000           0.0  0.000000           0.000000
# 5      0.000000            0.000000           0.0  0.000000           0.000000
# 6      0.000000            0.000000           0.0  0.000000           0.000000
# 7      0.000000            0.000000           0.0  0.000000           0.000000
# 8      0.250000            0.000000           0.0  0.000000           0.000000
# 9      0.000000            0.000000           0.0  0.000000           0.000000
# 10     0.000000            0.000000           0.0  0.000000           0.000000
# 11     0.000000            0.000000           0.0  0.000000           0.000000
# 12     0.000000            0.000000           0.0  0.038462           0.115385
# 13     0.000000            0.000000           0.0  0.000000           0.000000
# 14     0.000000            0.000000           0.0  0.000000           0.000000
# 15     0.111111            0.000000           0.0  0.000000           0.000000
# 16     0.000000            0.000000           0.2  0.000000           0.000000
# 17     0.000000            0.000000           0.0  0.000000           0.000000
# 18     0.000000            0.000000           0.0  0.000000           0.000000
# 19     0.000000            0.000000           0.0  0.000000           0.000000
#
# [20 rows x 64 columns]

# %%
# Print most common venues
num_top_venues =20

for hood in syracuse_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = syracuse_grouped[syracuse_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ---- Siracusa----
#                        venue  freq
# 0         Italian Restaurant  0.13
# 1                      Hotel  0.10
# 2         Seafood Restaurant  0.08
# 3                 Restaurant  0.05
# 4   Mediterranean Restaurant  0.05
# 5                     Bistro  0.03
# 6             Ice Cream Shop  0.03
# 7              Historic Site  0.03
# 8                       Café  0.03
# 9          Trattoria/Osteria  0.02
# 10        Miscellaneous Shop  0.02
# 11               Pizza Place  0.02
# 12                Food Court  0.02
# 13                Food Truck  0.02
# 14                  Fountain  0.02
# 15              Gourmet Shop  0.02
# 16                    Bakery  0.02
# 17     General Entertainment  0.02
# 18               Fish Market  0.02
# 19           Harbor / Marina  0.02
#
#
# ----Augusta----
#                        venue  freq
# 0             Ice Cream Shop  0.17
# 1                      Beach  0.17
# 2            Harbor / Marina  0.17
# 3         Seafood Restaurant  0.17
# 4           Sculpture Garden  0.17
# 5                Pizza Place  0.17
# 6                 Art Museum  0.00
# 7              Jewelry Store  0.00
# 8        Japanese Restaurant  0.00
# 9         Italian Restaurant  0.00
# 10       Indie Movie Theater  0.00
# 11             Historic Site  0.00
# 12                     Hotel  0.00
# 13                Kids Store  0.00
# 14   Health & Beauty Service  0.00
# 15            Hardware Store  0.00
# 16              Gourmet Shop  0.00
# 17          Kebab Restaurant  0.00
# 18  Mediterranean Restaurant  0.00
# 19                    Lounge  0.00
#
#
# ----Avola----
#                        venue  freq
# 0                       Café  0.50
# 1                  Gastropub  0.25
# 2                      Plaza  0.25
# 3                 Art Museum  0.00
# 4           Kebab Restaurant  0.00
# 5              Jewelry Store  0.00
# 6        Japanese Restaurant  0.00
# 7         Italian Restaurant  0.00
# 8        Indie Movie Theater  0.00
# 9             Ice Cream Shop  0.00
# 10                    Lounge  0.00
# 11                     Hotel  0.00
# 12             Historic Site  0.00
# 13   Health & Beauty Service  0.00
# 14            Hardware Store  0.00
# 15           Harbor / Marina  0.00
# 16                Kids Store  0.00
# 17  Mediterranean Restaurant  0.00
# 18                 Gift Shop  0.00
# 19        Miscellaneous Shop  0.00
#
#
# ----Buccheri----
#                        venue  freq
# 0                    Theater  0.33
# 1         Italian Restaurant  0.33
# 2                Pizza Place  0.33
# 3                 Art Museum  0.00
# 4                 Kids Store  0.00
# 5               Gourmet Shop  0.00
# 6            Harbor / Marina  0.00
# 7             Hardware Store  0.00
# 8    Health & Beauty Service  0.00
# 9              Historic Site  0.00
# 10                     Hotel  0.00
# 11            Ice Cream Shop  0.00
# 12       Indie Movie Theater  0.00
# 13       Japanese Restaurant  0.00
# 14             Jewelry Store  0.00
# 15          Kebab Restaurant  0.00
# 16  Mediterranean Restaurant  0.00
# 17                    Lounge  0.00
# 18     General Entertainment  0.00
# 19        Miscellaneous Shop  0.00
#
#
# ----Buscemi----
#                          venue  freq
# 0                  Flower Shop   0.5
# 1   Construction & Landscaping   0.5
# 2                   Art Museum   0.0
# 3                       Lounge   0.0
# 4              Harbor / Marina   0.0
# 5               Hardware Store   0.0
# 6      Health & Beauty Service   0.0
# 7                Historic Site   0.0
# 8                        Hotel   0.0
# 9               Ice Cream Shop   0.0
# 10         Indie Movie Theater   0.0
# 11          Italian Restaurant   0.0
# 12         Japanese Restaurant   0.0
# 13               Jewelry Store   0.0
# 14            Kebab Restaurant   0.0
# 15                  Kids Store   0.0
# 16    Mediterranean Restaurant   0.0
# 17                   Gift Shop   0.0
# 18          Miscellaneous Shop   0.0
# 19       Outdoors & Recreation   0.0
#
#
# ----Canicattini Bagni----
#                        venue  freq
# 0                 Art Museum  0.25
# 1                 Restaurant  0.25
# 2          Electronics Store  0.25
# 3                      Plaza  0.25
# 4              Jewelry Store  0.00
# 5        Japanese Restaurant  0.00
# 6         Italian Restaurant  0.00
# 7        Indie Movie Theater  0.00
# 8             Ice Cream Shop  0.00
# 9                 Kids Store  0.00
# 10                     Hotel  0.00
# 11             Historic Site  0.00
# 12   Health & Beauty Service  0.00
# 13            Hardware Store  0.00
# 14           Harbor / Marina  0.00
# 15              Gourmet Shop  0.00
# 16          Kebab Restaurant  0.00
# 17                    Lounge  0.00
# 18     General Entertainment  0.00
# 19  Mediterranean Restaurant  0.00
#
#
# ----Cassaro----
#                        venue  freq
# 0                 Restaurant   1.0
# 1                 Art Museum   0.0
# 2                     Lounge   0.0
# 3               Gourmet Shop   0.0
# 4            Harbor / Marina   0.0
# 5             Hardware Store   0.0
# 6    Health & Beauty Service   0.0
# 7              Historic Site   0.0
# 8                      Hotel   0.0
# 9             Ice Cream Shop   0.0
# 10       Indie Movie Theater   0.0
# 11        Italian Restaurant   0.0
# 12       Japanese Restaurant   0.0
# 13             Jewelry Store   0.0
# 14          Kebab Restaurant   0.0
# 15                Kids Store   0.0
# 16  Mediterranean Restaurant   0.0
# 17     General Entertainment   0.0
# 18        Miscellaneous Shop   0.0
# 19     Outdoors & Recreation   0.0
#
#
# ----Ferla----
#                        venue  freq
# 0                Pizza Place   1.0
# 1                 Art Museum   0.0
# 2                     Lounge   0.0
# 3               Gourmet Shop   0.0
# 4            Harbor / Marina   0.0
# 5             Hardware Store   0.0
# 6    Health & Beauty Service   0.0
# 7              Historic Site   0.0
# 8                      Hotel   0.0
# 9             Ice Cream Shop   0.0
# 10       Indie Movie Theater   0.0
# 11        Italian Restaurant   0.0
# 12       Japanese Restaurant   0.0
# 13             Jewelry Store   0.0
# 14          Kebab Restaurant   0.0
# 15                Kids Store   0.0
# 16  Mediterranean Restaurant   0.0
# 17     General Entertainment   0.0
# 18        Miscellaneous Shop   0.0
# 19     Outdoors & Recreation   0.0
#
#
# ----Floridia----
#                        venue  freq
# 0                 Kids Store  0.25
# 1                  Gastropub  0.25
# 2                Snack Place  0.25
# 3                       Café  0.25
# 4             Ice Cream Shop  0.00
# 5           Kebab Restaurant  0.00
# 6              Jewelry Store  0.00
# 7        Japanese Restaurant  0.00
# 8         Italian Restaurant  0.00
# 9        Indie Movie Theater  0.00
# 10                Art Museum  0.00
# 11                    Lounge  0.00
# 12             Historic Site  0.00
# 13   Health & Beauty Service  0.00
# 14            Hardware Store  0.00
# 15           Harbor / Marina  0.00
# 16                     Hotel  0.00
# 17  Mediterranean Restaurant  0.00
# 18                 Gift Shop  0.00
# 19        Miscellaneous Shop  0.00
#
#
# ----Francofonte----
#                        venue  freq
# 0                        Bar  0.25
# 1                 Food Court  0.25
# 2                      Plaza  0.25
# 3                        Pub  0.25
# 4                 Art Museum  0.00
# 5        Indie Movie Theater  0.00
# 6              Jewelry Store  0.00
# 7        Japanese Restaurant  0.00
# 8         Italian Restaurant  0.00
# 9                      Hotel  0.00
# 10            Ice Cream Shop  0.00
# 11                Kids Store  0.00
# 12             Historic Site  0.00
# 13   Health & Beauty Service  0.00
# 14            Hardware Store  0.00
# 15           Harbor / Marina  0.00
# 16          Kebab Restaurant  0.00
# 17  Mediterranean Restaurant  0.00
# 18                    Lounge  0.00
# 19                 Gift Shop  0.00
#
#
# ----Lentini----
#                       venue  freq
# 0                    Bakery  0.25
# 1              Cupcake Shop  0.25
# 2   Health & Beauty Service  0.25
# 3                     Plaza  0.25
# 4       Indie Movie Theater  0.00
# 5          Kebab Restaurant  0.00
# 6             Jewelry Store  0.00
# 7       Japanese Restaurant  0.00
# 8        Italian Restaurant  0.00
# 9            Ice Cream Shop  0.00
# 10                   Lounge  0.00
# 11                    Hotel  0.00
# 12            Historic Site  0.00
# 13           Hardware Store  0.00
# 14          Harbor / Marina  0.00
# 15             Gourmet Shop  0.00
# 16               Kids Store  0.00
# 17               Art Museum  0.00
# 18                Gift Shop  0.00
# 19       Miscellaneous Shop  0.00
#
#
# ----Melilli----
#                          venue  freq
# 0                          Bar  0.33
# 1   Construction & Landscaping  0.33
# 2                Jewelry Store  0.33
# 3                   Art Museum  0.00
# 4          Indie Movie Theater  0.00
# 5                   Kids Store  0.00
# 6             Kebab Restaurant  0.00
# 7          Japanese Restaurant  0.00
# 8           Italian Restaurant  0.00
# 9               Ice Cream Shop  0.00
# 10    Mediterranean Restaurant  0.00
# 11                       Hotel  0.00
# 12               Historic Site  0.00
# 13     Health & Beauty Service  0.00
# 14              Hardware Store  0.00
# 15             Harbor / Marina  0.00
# 16                      Lounge  0.00
# 17          Miscellaneous Shop  0.00
# 18                   Gift Shop  0.00
# 19       Outdoors & Recreation  0.00
#
#
# ----Noto----
#                   venue  freq
# 0                  Café  0.15
# 1     Trattoria/Osteria  0.12
# 2    Italian Restaurant  0.12
# 3            Restaurant  0.08
# 4                Bistro  0.08
# 5                 Plaza  0.08
# 6          Dessert Shop  0.04
# 7               Theater  0.04
# 8           Pizza Place  0.04
# 9         Historic Site  0.04
# 10           Food Court  0.04
# 11    Food & Drink Shop  0.04
# 12                Diner  0.04
# 13           Art Museum  0.04
# 14              Gay Bar  0.04
# 15          Coffee Shop  0.04
# 16              Brewery  0.00
# 17  Indie Movie Theater  0.00
# 18         Burger Joint  0.00
# 19  Japanese Restaurant  0.00
#
#
# ----Pachino----
#                        venue  freq
# 0        Indie Movie Theater  0.25
# 1                       Café  0.25
# 2                      Plaza  0.25
# 3             Clothing Store  0.25
# 4           Kebab Restaurant  0.00
# 5              Jewelry Store  0.00
# 6        Japanese Restaurant  0.00
# 7         Italian Restaurant  0.00
# 8                 Art Museum  0.00
# 9                     Lounge  0.00
# 10            Ice Cream Shop  0.00
# 11                     Hotel  0.00
# 12             Historic Site  0.00
# 13   Health & Beauty Service  0.00
# 14            Hardware Store  0.00
# 15           Harbor / Marina  0.00
# 16                Kids Store  0.00
# 17        Miscellaneous Shop  0.00
# 18  Mediterranean Restaurant  0.00
# 19                 Gift Shop  0.00
#
#
# ----Palazzolo Acreide----
#                        venue  freq
# 0                       Café   0.2
# 1               Dessert Shop   0.2
# 2                      Plaza   0.2
# 3               Cocktail Bar   0.2
# 4         Italian Restaurant   0.2
# 5                 Kids Store   0.0
# 6           Kebab Restaurant   0.0
# 7              Jewelry Store   0.0
# 8        Japanese Restaurant   0.0
# 9                 Art Museum   0.0
# 10       Indie Movie Theater   0.0
# 11            Ice Cream Shop   0.0
# 12                     Hotel   0.0
# 13             Historic Site   0.0
# 14   Health & Beauty Service   0.0
# 15            Hardware Store   0.0
# 16           Harbor / Marina   0.0
# 17                    Lounge   0.0
# 18        Miscellaneous Shop   0.0
# 19  Mediterranean Restaurant   0.0
#
#
# ----Portopalo di Capo Passero----
#                       venue  freq
# 0                      Café  0.11
# 1                      Food  0.11
# 2           Harbor / Marina  0.11
# 3                     Beach  0.11
# 4               Snack Place  0.11
# 5        Seafood Restaurant  0.11
# 6     Outdoors & Recreation  0.11
# 7                     Hotel  0.11
# 8                Restaurant  0.11
# 9       Japanese Restaurant  0.00
# 10       Italian Restaurant  0.00
# 11      Indie Movie Theater  0.00
# 12               Art Museum  0.00
# 13           Ice Cream Shop  0.00
# 14         Kebab Restaurant  0.00
# 15            Historic Site  0.00
# 16  Health & Beauty Service  0.00
# 17           Hardware Store  0.00
# 18            Jewelry Store  0.00
# 19       Miscellaneous Shop  0.00
#
#
# ----Priolo Gargallo----
#                        venue  freq
# 0                       Café   0.2
# 1               Tennis Court   0.2
# 2             Hardware Store   0.2
# 3                Pizza Place   0.2
# 4               Burger Joint   0.2
# 5        Indie Movie Theater   0.0
# 6           Kebab Restaurant   0.0
# 7              Jewelry Store   0.0
# 8        Japanese Restaurant   0.0
# 9         Italian Restaurant   0.0
# 10                Art Museum   0.0
# 11            Ice Cream Shop   0.0
# 12                    Lounge   0.0
# 13                     Hotel   0.0
# 14             Historic Site   0.0
# 15   Health & Beauty Service   0.0
# 16           Harbor / Marina   0.0
# 17                Kids Store   0.0
# 18        Miscellaneous Shop   0.0
# 19  Mediterranean Restaurant   0.0
#
#
# ----Rosolini----
#                        venue  freq
# 0                Pizza Place  0.25
# 1             Breakfast Spot  0.25
# 2               Burger Joint  0.25
# 3                        Pub  0.25
# 4                 Art Museum  0.00
# 5        Indie Movie Theater  0.00
# 6           Kebab Restaurant  0.00
# 7              Jewelry Store  0.00
# 8        Japanese Restaurant  0.00
# 9         Italian Restaurant  0.00
# 10            Ice Cream Shop  0.00
# 11                    Lounge  0.00
# 12                     Hotel  0.00
# 13             Historic Site  0.00
# 14   Health & Beauty Service  0.00
# 15            Hardware Store  0.00
# 16           Harbor / Marina  0.00
# 17                Kids Store  0.00
# 18        Miscellaneous Shop  0.00
# 19  Mediterranean Restaurant  0.00
#
#
# ----Solarino----
#                          venue  freq
# 0                         Café  0.17
# 1                Design Studio  0.17
# 2                   Food Truck  0.17
# 3                  Pizza Place  0.17
# 4   Construction & Landscaping  0.17
# 5                        Plaza  0.17
# 6           Italian Restaurant  0.00
# 7             Kebab Restaurant  0.00
# 8                Jewelry Store  0.00
# 9          Japanese Restaurant  0.00
# 10                  Art Museum  0.00
# 11                      Lounge  0.00
# 12         Indie Movie Theater  0.00
# 13              Ice Cream Shop  0.00
# 14                       Hotel  0.00
# 15               Historic Site  0.00
# 16     Health & Beauty Service  0.00
# 17              Hardware Store  0.00
# 18                  Kids Store  0.00
# 19          Miscellaneous Shop  0.00
#
#
# ----Sortino----
#                       venue  freq
# 0               Pizza Place   0.4
# 1                 Gift Shop   0.2
# 2                Restaurant   0.2
# 3                     Plaza   0.2
# 4             Jewelry Store   0.0
# 5       Japanese Restaurant   0.0
# 6        Italian Restaurant   0.0
# 7       Indie Movie Theater   0.0
# 8            Ice Cream Shop   0.0
# 9                Kids Store   0.0
# 10                    Hotel   0.0
# 11            Historic Site   0.0
# 12  Health & Beauty Service   0.0
# 13           Hardware Store   0.0
# 14          Harbor / Marina   0.0
# 15             Gourmet Shop   0.0
# 16         Kebab Restaurant   0.0
# 17               Art Museum   0.0
# 18                   Lounge   0.0
# 19    General Entertainment   0.0

# %%
# Sort in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# Seventh stage: reformat DataFrame according to observations
import numpy as np

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = syracuse_grouped['Neighborhood']

for ind in np.arange(syracuse_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(syracuse_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#   Neighborhood 1st Most Common Venue       2nd Most Common Venue  \
# 0     Siracusa    Italian Restaurant                       Hotel
# 1      Augusta        Ice Cream Shop                       Beach
# 2        Avola                  Café                   Gastropub
# 3     Buccheri               Theater          Italian Restaurant
# 4      Buscemi           Flower Shop  Construction & Landscaping
#
#   3rd Most Common Venue 4th Most Common Venue     5th Most Common Venue  \
# 0    Seafood Restaurant            Restaurant  Mediterranean Restaurant
# 1    Seafood Restaurant      Sculpture Garden           Harbor / Marina
# 2                 Plaza        Farmers Market             Design Studio
# 3           Pizza Place     Trattoria/Osteria            Farmers Market
# 4     Trattoria/Osteria          Cupcake Shop                Food Truck
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0        Ice Cream Shop                  Café                Bistro
# 1           Pizza Place     Trattoria/Osteria        Farmers Market
# 2          Dessert Shop                 Diner     Electronics Store
# 3         Design Studio          Dessert Shop                 Diner
# 4            Food Court     Food & Drink Shop                  Food
#
#   9th Most Common Venue 10th Most Common Venue
# 0         Historic Site               Creperie
# 1         Design Studio           Dessert Shop
# 2     Trattoria/Osteria          Deli / Bodega
# 3     Electronics Store   Fast Food Restaurant
# 4           Fish Market   Fast Food Restaurant

# %% [markdown]
# ## Cluster neighborhoods

# %%
#Eighth stage: Cluster neighborhoods

from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

syracuse_grouped_clustering = syracuse_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(syracuse_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 3, 0, 2, 0, 1, 4, 3, 0])

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

syracuse_merged = syracuse_province

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
syracuse_merged = syracuse_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Comune')

syracuse_merged.head()
# Out:
#       Comune  Superficie Popolazione Latitude Longitude  Cluster Labels  \
# 0   Siracusa  204,10 km2     123.850  37.0646   15.2907             0.0
# 1    Augusta  109,30 km2      34.539  37.2369   15.2197             0.0
# 2      Avola   74,30 km2      31.827  36.9095    15.135             3.0
# 3   Buccheri   57,40 km2       2.148  37.1265   14.8504             0.0
# 4    Buscemi   51,60 km2       1.147  37.0855   14.8842             2.0
#
#   1st Most Common Venue       2nd Most Common Venue 3rd Most Common Venue  \
# 0    Italian Restaurant                       Hotel    Seafood Restaurant
# 1        Ice Cream Shop                       Beach    Seafood Restaurant
# 2                  Café                   Gastropub                 Plaza
# 3               Theater          Italian Restaurant           Pizza Place
# 4           Flower Shop  Construction & Landscaping     Trattoria/Osteria
#
#   4th Most Common Venue     5th Most Common Venue 6th Most Common Venue  \
# 0            Restaurant  Mediterranean Restaurant        Ice Cream Shop
# 1      Sculpture Garden           Harbor / Marina           Pizza Place
# 2        Farmers Market             Design Studio          Dessert Shop
# 3     Trattoria/Osteria            Farmers Market         Design Studio
# 4          Cupcake Shop                Food Truck            Food Court
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0                  Café                Bistro         Historic Site
# 1     Trattoria/Osteria        Farmers Market         Design Studio
# 2                 Diner     Electronics Store     Trattoria/Osteria
# 3          Dessert Shop                 Diner     Electronics Store
# 4     Food & Drink Shop                  Food           Fish Market
#
#   10th Most Common Venue
# 0               Creperie
# 1           Dessert Shop
# 2          Deli / Bodega
# 3   Fast Food Restaurant
# 4   Fast Food Restaurant

# %% [markdown]
# # Results
#
# - Our model show that the whole area can be divided into 5 or 4 clusters, with a single red cluster being bigger than all the others together.
#     - This red cluster also includes Syracuse, making it the most suitable place after the green cluster to make businness.

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

syracuse_merged["Cluster Labels"] = syracuse_merged["Cluster Labels"]

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(syracuse_merged['Latitude'], syracuse_merged['Longitude'], syracuse_merged['Comune'], syracuse_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    try:
        folium.CircleMarker(
                [lat, lon],
                radius=5,
                popup=label,
                color=rainbow[int(cluster)-1],
                fill=True,
                fill_color=rainbow[int(cluster)-1],
                fill_opacity=0.7).add_to(map_clusters)
    except:
        folium.CircleMarker(
                [lat, lon],
                radius=5,
                popup=label,
                color=rainbow[0-1],
                fill=True,
                fill_color=rainbow[0-1],
                fill_opacity=0.7).add_to(map_clusters)
    

       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examination of most profitable activities

# %%
red_cluster = syracuse_merged.loc[syracuse_merged['Cluster Labels'] == 0, syracuse_merged.columns[[0] + list(range(1, syracuse_merged.shape[1]))]]

red_cluster
# Out:
#                        Comune  Superficie Popolazione Latitude Longitude  \
# 0                    Siracusa  204,10 km2     123.850  37.0646   15.2907
# 1                     Augusta  109,30 km2      34.539  37.2369   15.2197
# 3                    Buccheri   57,40 km2       2.148  37.1265   14.8504
# 5           Canicattini Bagni   15,10 km2       7.355  37.0349   15.0623
# 10                Francofonte   74,00 km2      12.392  37.2266   14.8819
# 11                    Lentini  215,80 km2      24.017  37.2847   14.9988
# 12                    Melilli  136,10 km2      13.304  37.1783   15.1266
# 16  Portopalo di Capo Passero   14,90 km2       3.818  36.6838   15.1333
# 18                   Rosolini   76,20 km2      21.798  36.8205   14.9526
# 20                    Sortino   93,20 km2       8.955  37.1569   15.0277
#
#     Cluster Labels    1st Most Common Venue 2nd Most Common Venue  \
# 0              0.0       Italian Restaurant                 Hotel
# 1              0.0           Ice Cream Shop                 Beach
# 3              0.0                  Theater    Italian Restaurant
# 5              0.0               Art Museum                 Plaza
# 10             0.0                    Plaza            Food Court
# 11             0.0  Health & Beauty Service                 Plaza
# 12             0.0            Jewelry Store                   Bar
# 16             0.0                     Café                  Food
# 18             0.0                      Pub        Breakfast Spot
# 20             0.0              Pizza Place                 Plaza
#
#          3rd Most Common Venue 4th Most Common Venue  \
# 0           Seafood Restaurant            Restaurant
# 1           Seafood Restaurant      Sculpture Garden
# 3                  Pizza Place     Trattoria/Osteria
# 5            Electronics Store            Restaurant
# 10                         Bar                   Pub
# 11                      Bakery          Cupcake Shop
# 12  Construction & Landscaping  Fast Food Restaurant
# 16                 Snack Place    Seafood Restaurant
# 18                Burger Joint           Pizza Place
# 20                   Gift Shop            Restaurant
#
#        5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0   Mediterranean Restaurant        Ice Cream Shop                  Café
# 1            Harbor / Marina           Pizza Place     Trattoria/Osteria
# 3             Farmers Market         Design Studio          Dessert Shop
# 5                       Food           Flower Shop           Fish Market
# 10         Trattoria/Osteria         Design Studio          Dessert Shop
# 11             Design Studio          Dessert Shop                 Diner
# 12             Design Studio          Dessert Shop                 Diner
# 16                     Beach                 Hotel            Restaurant
# 18      Fast Food Restaurant         Design Studio          Dessert Shop
# 20         Trattoria/Osteria         Deli / Bodega         Design Studio
#
#    8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 0                 Bistro          Historic Site               Creperie
# 1         Farmers Market          Design Studio           Dessert Shop
# 3                  Diner      Electronics Store   Fast Food Restaurant
# 5   Fast Food Restaurant               Creperie         Farmers Market
# 10                 Diner      Electronics Store         Farmers Market
# 11     Electronics Store         Farmers Market      Trattoria/Osteria
# 12     Electronics Store         Farmers Market      Trattoria/Osteria
# 16       Harbor / Marina  Outdoors & Recreation      Trattoria/Osteria
# 18                 Diner      Electronics Store         Farmers Market
# 20          Dessert Shop                  Diner      Electronics Store

# %%
green_cluster = syracuse_merged.loc[syracuse_merged['Cluster Labels'] == 3, syracuse_merged.columns[[0] + list(range(1, syracuse_merged.shape[1]))]]
green_cluster
# Out:
#                Comune  Superficie Popolazione Latitude Longitude  \
# 2               Avola   74,30 km2      31.827  36.9095    15.135
# 9            Floridia   26,20 km2      23.050  37.0869   15.1519
# 13               Noto  551,10 km2      24.047  36.8909   15.0706
# 14            Pachino   50,50 km2      21.990  36.7152   15.0915
# 15  Palazzolo Acreide   86,30 km2       9.061  37.0619   14.9039
# 17    Priolo Gargallo   57,60 km2      12.148  37.1579    15.186
# 19           Solarino   13,00 km2       7.820  37.1012    15.119
#
#     Cluster Labels       1st Most Common Venue 2nd Most Common Venue  \
# 2              3.0                        Café             Gastropub
# 9              3.0                  Kids Store           Snack Place
# 13             3.0                        Café     Trattoria/Osteria
# 14             3.0         Indie Movie Theater        Clothing Store
# 15             3.0          Italian Restaurant          Dessert Shop
# 17             3.0                Burger Joint          Tennis Court
# 19             3.0  Construction & Landscaping                 Plaza
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 2                  Plaza        Farmers Market         Design Studio
# 9                   Café             Gastropub                   Bar
# 13    Italian Restaurant                Bistro            Restaurant
# 14                  Café                 Plaza     Trattoria/Osteria
# 15          Cocktail Bar                  Café                 Plaza
# 17                  Café        Hardware Store           Pizza Place
# 19         Design Studio                  Café           Pizza Place
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 2           Dessert Shop                 Diner     Electronics Store
# 9          Deli / Bodega            Food Truck            Food Court
# 13                 Plaza           Coffee Shop          Dessert Shop
# 14     Electronics Store          Dessert Shop                 Diner
# 15     Trattoria/Osteria     Electronics Store                 Diner
# 17  Fast Food Restaurant          Dessert Shop                 Diner
# 19            Food Truck        Breakfast Spot               Brewery
#
#    9th Most Common Venue 10th Most Common Venue
# 2      Trattoria/Osteria          Deli / Bodega
# 9      Food & Drink Shop                   Food
# 13                 Diner      Food & Drink Shop
# 14        Farmers Market          Deli / Bodega
# 15        Farmers Market          Deli / Bodega
# 17     Electronics Store         Farmers Market
# 19            Food Court      Food & Drink Shop

# %% [markdown]
# # Discussion and Conclusion

# %% [markdown]
# So, let's say we want to open a Cafè businness just using the data we have. Let's take a look to which are the best places on both clusters. Further analysis are out of scope for this project.

# %%
businness_target= "Café"
suitable_places = []
clusters = [red_cluster,green_cluster]

# Search inside the clusters for suitable places
pointer = 0

for cluster in clusters:
    for index, row in cluster.iterrows():
        if row["1st Most Common Venue"] == businness_target:
            suitable_places.append([])
            suitable_places[pointer].append(row["Comune"])
            suitable_places[pointer].append(row["Cluster Labels"])
            suitable_places[pointer].append(row["Popolazione"])
            suitable_places[pointer].append(row["Latitude"])
            suitable_places[pointer].append(row["Longitude"])
            pointer += 1
    
population = 0
best_index = 0
print("Places to open a {} businness are: ".format(businness_target))
for i in range(len(suitable_places)):
    try:
        population = int(population.replace(".",""))
    except:
        pass
    
    if population < int(suitable_places[i][2].replace(".","")):
        population = suitable_places[i][2]
        best_index = i
    print("\tCity of {}, cluster number: {}, population number: {}".format(suitable_places[i][0],suitable_places[i][1],suitable_places[i][2]))

print("\n\nBest place chosen by population number is: {} ".format(suitable_places[best_index][0]))
# Out:
# Places to open a Café businness are:
# 	City of Portopalo di Capo Passero, cluster number: 0.0, population number: 3.818
# 	City of Avola, cluster number: 3.0, population number: 31.827
# 	City of Noto, cluster number: 3.0, population number: 24.047
#
#
# Best place chosen by population number is: Avola
